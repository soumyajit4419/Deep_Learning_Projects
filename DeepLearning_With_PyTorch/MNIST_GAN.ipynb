# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torchvision.transforms import transforms
from torchvision.datasets import MNIST
from torch.utils.data import DataLoader
from torchvision.utils import make_grid

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
transform = transforms.Compose([
                                transforms.ToTensor(),
                                transforms.Normalize(mean=(0.5),std=(0.5,)) #Converting 0 to 1px to -1 to 1px
                              ])

dataset = MNIST(root='./data',train=True,transform=transform,download=True)

# %%
img,label = dataset[0]
plt.imshow(img[0], cmap='gray')
print('Label:', label)
print("shape: ",img.shape)
# Out:
# Label: 5
# shape:  torch.Size([1, 28, 28])

# %%
batch_size=100
train_loader = DataLoader(dataset,batch_size=batch_size,shuffle=True,num_workers=3,pin_memory=True)

# %%
def denorm(x):
    out = (x + 1) / 2
    return out.clamp(0, 1)

# %%
for images,labels in train_loader:
  print(images.shape)
  plt.figure(figsize=(12,10))
  plt.imshow(make_grid(denorm(images),nrow=16).permute(1,2,0))
  plt.axis('off')
  break
# Out:
# torch.Size([100, 1, 28, 28])

# %%
def get_device():
  if torch.cuda.is_available():
    return torch.device('cuda')
  else:
    return torch.device('cpu')

# %%
device = get_device()
device
# Out:
# device(type='cuda')

# %%
image_size = 784
hidden_size = 256
latent_size = 64

# %%
D = nn.Sequential(
    nn.Linear(image_size, hidden_size),
    nn.LeakyReLU(0.2),
    nn.Linear(hidden_size, hidden_size),
    nn.LeakyReLU(0.2),
    nn.Linear(hidden_size, 1),
    nn.Sigmoid())

# %%
D = D.to(device)

# %%
D
# Out:
# Sequential(
#   (0): Linear(in_features=784, out_features=256, bias=True)
#   (1): LeakyReLU(negative_slope=0.2)
#   (2): Linear(in_features=256, out_features=256, bias=True)
#   (3): LeakyReLU(negative_slope=0.2)
#   (4): Linear(in_features=256, out_features=1, bias=True)
#   (5): Sigmoid()
# )

# %%
G = nn.Sequential(
    nn.Linear(latent_size, hidden_size),
    nn.ReLU(),
    nn.Linear(hidden_size, hidden_size),
    nn.ReLU(),
    nn.Linear(hidden_size, image_size),
    nn.Tanh())

# %%
G
# Out:
# Sequential(
#   (0): Linear(in_features=64, out_features=256, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=256, out_features=256, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=256, out_features=784, bias=True)
#   (5): Tanh()
# )

# %%
xb = torch.randn(2,64)
y = G(xb)
gen_imgs = y.reshape((-1, 28,28)).detach()

# %%
plt.imshow(denorm(gen_imgs[0]), cmap='gray');

# %%
plt.imshow(denorm(gen_imgs[1]), cmap='gray');

# %%
G = G.to(device)

# %%
d_optimizer = torch.optim.Adam(D.parameters(), lr=0.0002)
g_optimizer = torch.optim.Adam(G.parameters(), lr=0.0002)

# %%
criterion = nn.BCELoss()

# %%
def reset_grad():
    d_optimizer.zero_grad()
    g_optimizer.zero_grad()

def train_discriminator(images):
    # Create the labels which are later used as input for the BCE loss
    real_labels = torch.ones(batch_size, 1).to(device)
    fake_labels = torch.zeros(batch_size, 1).to(device)
        
    # Loss for real images
    outputs = D(images)
    d_loss_real = criterion(outputs, real_labels)
    real_score = outputs

    # Loss for fake images
    z = torch.randn(batch_size, latent_size).to(device)
    fake_images = G(z)
    outputs = D(fake_images)
    d_loss_fake = criterion(outputs, fake_labels)
    fake_score = outputs

    # Combine losses
    d_loss = d_loss_real + d_loss_fake
    # Reset gradients
    reset_grad()
    # Compute gradients
    d_loss.backward()
    # Adjust the parameters using backprop
    d_optimizer.step()
    
    return d_loss, real_score, fake_score

# %%
def train_generator():
    # Generate fake images and calculate loss
    z = torch.randn(batch_size, latent_size).to(device)
    fake_images = G(z)
    labels = torch.ones(batch_size, 1).to(device)
    g_loss = F.binary_cross_entropy(D(fake_images), labels)

    # Backprop and optimize
    reset_grad()
    g_loss.backward()
    g_optimizer.step()
    return g_loss, fake_images

# %%
import os

sample_dir = 'samples'
if not os.path.exists(sample_dir):
    os.makedirs(sample_dir)

# %%
from IPython.display import Image
from torchvision.utils import save_image


# Save some real images
for images, _ in train_loader:
    images = images.reshape(images.size(0), 1, 28, 28)
    save_image(denorm(images), os.path.join(sample_dir, 'real_images.png'), nrow=16)
    break
   
Image(os.path.join(sample_dir, 'real_images.png'))

# %%
sample_vectors = torch.randn(100, latent_size).to(device)

def save_fake_images(index):
    fake_images = G(sample_vectors)
    fake_images = fake_images.reshape(fake_images.size(0), 1, 28, 28)
    fake_fname = 'fake_images-{0:0=4d}.png'.format(index)
    print('Saving', fake_fname)
    save_image(denorm(fake_images), os.path.join(sample_dir, fake_fname), nrow=10)
    
# Before training
save_fake_images(0)
Image(os.path.join(sample_dir, 'fake_images-0000.png'))
# Out:
# Saving fake_images-0000.png

# %%
num_epochs = 300
total_step = len(train_loader)
d_losses, g_losses, real_scores, fake_scores = [], [], [], []

for epoch in range(num_epochs):
    for i, (images, _) in enumerate(train_loader):
        # Load a batch & transform to vectors
        images = images.reshape(batch_size,-1).to(device)
        
        # Train the discriminator and generator
        d_loss, real_score, fake_score = train_discriminator(images)
        g_loss, fake_images = train_generator()
        
        # Inspect the losses
        if (i+1) % 200 == 0:
            d_losses.append(d_loss.item())
            g_losses.append(g_loss.item())
            real_scores.append(real_score.mean().item())
            fake_scores.append(fake_score.mean().item())
            print('Epoch [{}/{}], Step [{}/{}], d_loss: {:.4f}, g_loss: {:.4f}, D(x): {:.2f}, D(G(z)): {:.2f}' 
                  .format(epoch, num_epochs, i+1, total_step, d_loss.item(), g_loss.item(),real_score.mean().item(), fake_score.mean().item()))
        
    # Sample and save images
    save_fake_images(epoch+1)
# Out:
# Epoch [0/300], Step [200/600], d_loss: 0.0309, g_loss: 4.1035, D(x): 1.00, D(G(z)): 0.03
# Epoch [0/300], Step [400/600], d_loss: 0.0752, g_loss: 5.6310, D(x): 0.99, D(G(z)): 0.06
# Epoch [0/300], Step [600/600], d_loss: 0.0325, g_loss: 5.0805, D(x): 0.99, D(G(z)): 0.02
# Saving fake_images-0001.png
# Epoch [1/300], Step [200/600], d_loss: 0.1229, g_loss: 5.4888, D(x): 0.96, D(G(z)): 0.04
# Epoch [1/300], Step [400/600], d_loss: 0.2544, g_loss: 3.2874, D(x): 0.93, D(G(z)): 0.13
# Epoch [1/300], Step [600/600], d_loss: 0.2618, g_loss: 4.7471, D(x): 0.95, D(G(z)): 0.14
# Saving fake_images-0002.png
# Epoch [2/300], Step [200/600], d_loss: 0.0792, g_loss: 4.3565, D(x): 0.98, D(G(z)): 0.05
# Epoch [2/300], Step [400/600], d_loss: 0.9047, g_loss: 1.9502, D(x): 0.76, D(G(z)): 0.30
# Epoch [2/300], Step [600/600], d_loss: 0.8823, g_loss: 2.3971, D(x): 0.80, D(G(z)): 0.24
# Saving fake_images-0003.png
# Epoch [3/300], Step [200/600], d_loss: 0.5983, g_loss: 3.5357, D(x): 0.85, D(G(z)): 0.26
# Epoch [3/300], Step [400/600], d_loss: 0.5319, g_loss: 2.4821, D(x): 0.80, D(G(z)): 0.12
# Epoch [3/300], Step [600/600], d_loss: 0.3602, g_loss: 2.7172, D(x): 0.87, D(G(z)): 0.15
# Saving fake_images-0004.png
# Epoch [4/300], Step [200/600], d_loss: 0.2666, g_loss: 2.8515, D(x): 0.93, D(G(z)): 0.14
# Epoch [4/300], Step [400/600], d_loss: 0.4878, g_loss: 3.3031, D(x): 0.87, D(G(z)): 0.14
# Epoch [4/300], Step [600/600], d_loss: 0.1173, g_loss: 3.6972, D(x): 0.97, D(G(z)): 0.07
# Saving fake_images-0005.png
# Epoch [5/300], Step [200/600], d_loss: 0.6262, g_loss: 2.9746, D(x): 0.84, D(G(z)): 0.25
# Epoch [5/300], Step [400/600], d_loss: 0.1766, g_loss: 3.7017, D(x): 0.94, D(G(z)): 0.05
# Epoch [5/300], Step [600/600], d_loss: 0.0923, g_loss: 4.2164, D(x): 0.97, D(G(z)): 0.06
# Saving fake_images-0006.png
# Epoch [6/300], Step [200/600], d_loss: 0.1494, g_loss: 3.8453, D(x): 0.96, D(G(z)): 0.06
# Epoch [6/300], Step [400/600], d_loss: 0.3125, g_loss: 3.3286, D(x): 0.92, D(G(z)): 0.03
# Epoch [6/300], Step [600/600], d_loss: 0.2477, g_loss: 2.8676, D(x): 0.95, D(G(z)): 0.13
# Saving fake_images-0007.png
# Epoch [7/300], Step [200/600], d_loss: 0.0961, g_loss: 4.9429, D(x): 0.97, D(G(z)): 0.02
# Epoch [7/300], Step [400/600], d_loss: 0.0999, g_loss: 5.7801, D(x): 0.97, D(G(z)): 0.05
# Epoch [7/300], Step [600/600], d_loss: 0.1520, g_loss: 5.2428, D(x): 0.99, D(G(z)): 0.11
# Saving fake_images-0008.png
# Epoch [8/300], Step [200/600], d_loss: 0.1280, g_loss: 4.9034, D(x): 0.97, D(G(z)): 0.04
# Epoch [8/300], Step [400/600], d_loss: 0.0751, g_loss: 5.9534, D(x): 0.96, D(G(z)): 0.02
# Epoch [8/300], Step [600/600], d_loss: 0.1734, g_loss: 4.3312, D(x): 0.96, D(G(z)): 0.09
# Saving fake_images-0009.png
# Epoch [9/300], Step [200/600], d_loss: 0.0594, g_loss: 5.5290, D(x): 0.98, D(G(z)): 0.03
# Epoch [9/300], Step [400/600], d_loss: 0.1003, g_loss: 5.6468, D(x): 0.96, D(G(z)): 0.02
# Epoch [9/300], Step [600/600], d_loss: 0.1162, g_loss: 5.2064, D(x): 0.97, D(G(z)): 0.04
# Saving fake_images-0010.png
# Epoch [10/300], Step [200/600], d_loss: 0.0309, g_loss: 6.7927, D(x): 0.99, D(G(z)): 0.02
# Epoch [10/300], Step [400/600], d_loss: 0.2139, g_loss: 6.1970, D(x): 0.95, D(G(z)): 0.02
# Epoch [10/300], Step [600/600], d_loss: 0.0876, g_loss: 4.4248, D(x): 0.98, D(G(z)): 0.05
# Saving fake_images-0011.png
# Epoch [11/300], Step [200/600], d_loss: 0.1343, g_loss: 6.7754, D(x): 0.97, D(G(z)): 0.06
# Epoch [11/300], Step [400/600], d_loss: 0.0890, g_loss: 5.5378, D(x): 0.97, D(G(z)): 0.05
# Epoch [11/300], Step [600/600], d_loss: 0.2988, g_loss: 5.3800, D(x): 0.91, D(G(z)): 0.03
# Saving fake_images-0012.png
# Epoch [12/300], Step [200/600], d_loss: 0.2201, g_loss: 4.1945, D(x): 0.92, D(G(z)): 0.04
# Epoch [12/300], Step [400/600], d_loss: 0.1512, g_loss: 4.4269, D(x): 0.95, D(G(z)): 0.05
# Epoch [12/300], Step [600/600], d_loss: 0.2678, g_loss: 5.2670, D(x): 0.94, D(G(z)): 0.09
# Saving fake_images-0013.png
# Epoch [13/300], Step [200/600], d_loss: 0.2265, g_loss: 3.4337, D(x): 0.93, D(G(z)): 0.06
# Epoch [13/300], Step [400/600], d_loss: 0.1910, g_loss: 5.2006, D(x): 0.94, D(G(z)): 0.05
# Epoch [13/300], Step [600/600], d_loss: 0.2467, g_loss: 5.8270, D(x): 0.96, D(G(z)): 0.10
# Saving fake_images-0014.png
# Epoch [14/300], Step [200/600], d_loss: 0.2822, g_loss: 4.3550, D(x): 0.86, D(G(z)): 0.01
# Epoch [14/300], Step [400/600], d_loss: 0.1527, g_loss: 5.0973, D(x): 0.95, D(G(z)): 0.02
# Epoch [14/300], Step [600/600], d_loss: 0.2082, g_loss: 3.5859, D(x): 0.95, D(G(z)): 0.10
# Saving fake_images-0015.png
# Epoch [15/300], Step [200/600], d_loss: 0.1346, g_loss: 5.5677, D(x): 0.95, D(G(z)): 0.02
# Epoch [15/300], Step [400/600], d_loss: 0.1123, g_loss: 4.6362, D(x): 0.95, D(G(z)): 0.05
# Epoch [15/300], Step [600/600], d_loss: 0.1225, g_loss: 5.3145, D(x): 0.99, D(G(z)): 0.08
# Saving fake_images-0016.png
# Epoch [16/300], Step [200/600], d_loss: 0.4545, g_loss: 6.1899, D(x): 0.86, D(G(z)): 0.05
# Epoch [16/300], Step [400/600], d_loss: 0.1057, g_loss: 5.0414, D(x): 0.95, D(G(z)): 0.03
# Epoch [16/300], Step [600/600], d_loss: 0.4163, g_loss: 3.2293, D(x): 0.89, D(G(z)): 0.07
# Saving fake_images-0017.png
# Epoch [17/300], Step [200/600], d_loss: 0.3128, g_loss: 2.2888, D(x): 0.89, D(G(z)): 0.07
# Epoch [17/300], Step [400/600], d_loss: 0.1836, g_loss: 4.0483, D(x): 0.95, D(G(z)): 0.07
# Epoch [17/300], Step [600/600], d_loss: 0.4136, g_loss: 4.9849, D(x): 0.87, D(G(z)): 0.03
# Saving fake_images-0018.png
# Epoch [18/300], Step [200/600], d_loss: 0.0872, g_loss: 4.6379, D(x): 0.99, D(G(z)): 0.07
# Epoch [18/300], Step [400/600], d_loss: 0.1852, g_loss: 4.7225, D(x): 0.95, D(G(z)): 0.07
# Epoch [18/300], Step [600/600], d_loss: 0.4028, g_loss: 5.2649, D(x): 0.90, D(G(z)): 0.03
# Saving fake_images-0019.png
# Epoch [19/300], Step [200/600], d_loss: 0.1439, g_loss: 4.7964, D(x): 0.97, D(G(z)): 0.04
# Epoch [19/300], Step [400/600], d_loss: 0.1658, g_loss: 5.7246, D(x): 0.99, D(G(z)): 0.12
# Epoch [19/300], Step [600/600], d_loss: 0.3092, g_loss: 4.8374, D(x): 0.90, D(G(z)): 0.03
# Saving fake_images-0020.png
# Epoch [20/300], Step [200/600], d_loss: 0.2071, g_loss: 4.0974, D(x): 0.98, D(G(z)): 0.13
# Epoch [20/300], Step [400/600], d_loss: 0.1259, g_loss: 4.6359, D(x): 0.97, D(G(z)): 0.07
# Epoch [20/300], Step [600/600], d_loss: 0.2904, g_loss: 4.0135, D(x): 0.94, D(G(z)): 0.10
# Saving fake_images-0021.png
# Epoch [21/300], Step [200/600], d_loss: 0.2581, g_loss: 7.9709, D(x): 0.93, D(G(z)): 0.03
# Epoch [21/300], Step [400/600], d_loss: 0.2587, g_loss: 3.6840, D(x): 0.89, D(G(z)): 0.05
# Epoch [21/300], Step [600/600], d_loss: 0.3034, g_loss: 4.0290, D(x): 0.93, D(G(z)): 0.11
# Saving fake_images-0022.png
# Epoch [22/300], Step [200/600], d_loss: 0.2671, g_loss: 5.0133, D(x): 0.93, D(G(z)): 0.06
# Epoch [22/300], Step [400/600], d_loss: 0.2236, g_loss: 4.4107, D(x): 0.93, D(G(z)): 0.06
# Epoch [22/300], Step [600/600], d_loss: 0.1954, g_loss: 5.5783, D(x): 0.92, D(G(z)): 0.03
# Saving fake_images-0023.png
# Epoch [23/300], Step [200/600], d_loss: 0.2865, g_loss: 4.5412, D(x): 0.92, D(G(z)): 0.09
# Epoch [23/300], Step [400/600], d_loss: 0.1811, g_loss: 5.2610, D(x): 0.95, D(G(z)): 0.06
# Epoch [23/300], Step [600/600], d_loss: 0.2102, g_loss: 4.1996, D(x): 0.97, D(G(z)): 0.11
# Saving fake_images-0024.png
# Epoch [24/300], Step [200/600], d_loss: 0.2304, g_loss: 4.4609, D(x): 0.96, D(G(z)): 0.12
# Epoch [24/300], Step [400/600], d_loss: 0.2975, g_loss: 4.5248, D(x): 0.88, D(G(z)): 0.04
# Epoch [24/300], Step [600/600], d_loss: 0.2643, g_loss: 4.0000, D(x): 0.94, D(G(z)): 0.11
# Saving fake_images-0025.png
# Epoch [25/300], Step [200/600], d_loss: 0.1888, g_loss: 4.7035, D(x): 0.95, D(G(z)): 0.09
# Epoch [25/300], Step [400/600], d_loss: 0.4002, g_loss: 4.3670, D(x): 0.87, D(G(z)): 0.06
# Epoch [25/300], Step [600/600], d_loss: 0.3680, g_loss: 3.1833, D(x): 0.90, D(G(z)): 0.13
# Saving fake_images-0026.png
# Epoch [26/300], Step [200/600], d_loss: 0.2149, g_loss: 3.6388, D(x): 0.96, D(G(z)): 0.10
# Epoch [26/300], Step [400/600], d_loss: 0.4840, g_loss: 3.5395, D(x): 0.88, D(G(z)): 0.13
# Epoch [26/300], Step [600/600], d_loss: 0.3151, g_loss: 4.5572, D(x): 0.85, D(G(z)): 0.02
# Saving fake_images-0027.png
# Epoch [27/300], Step [200/600], d_loss: 0.3423, g_loss: 3.6974, D(x): 0.94, D(G(z)): 0.17
# Epoch [27/300], Step [400/600], d_loss: 0.2914, g_loss: 4.6001, D(x): 0.89, D(G(z)): 0.05
# Epoch [27/300], Step [600/600], d_loss: 0.3143, g_loss: 3.1321, D(x): 0.89, D(G(z)): 0.09
# Saving fake_images-0028.png
# Epoch [28/300], Step [200/600], d_loss: 0.3559, g_loss: 3.4979, D(x): 0.85, D(G(z)): 0.06
# Epoch [28/300], Step [400/600], d_loss: 0.4942, g_loss: 3.0902, D(x): 0.82, D(G(z)): 0.08
# Epoch [28/300], Step [600/600], d_loss: 0.3230, g_loss: 3.5861, D(x): 0.94, D(G(z)): 0.17
# Saving fake_images-0029.png
# Epoch [29/300], Step [200/600], d_loss: 0.2544, g_loss: 4.6130, D(x): 0.92, D(G(z)): 0.10
# Epoch [29/300], Step [400/600], d_loss: 0.1096, g_loss: 4.5957, D(x): 0.97, D(G(z)): 0.05
# Epoch [29/300], Step [600/600], d_loss: 0.4096, g_loss: 4.4468, D(x): 0.87, D(G(z)): 0.06
# Saving fake_images-0030.png
# Epoch [30/300], Step [200/600], d_loss: 0.3678, g_loss: 3.9585, D(x): 0.94, D(G(z)): 0.19
# Epoch [30/300], Step [400/600], d_loss: 0.1628, g_loss: 3.2525, D(x): 0.91, D(G(z)): 0.04
# Epoch [30/300], Step [600/600], d_loss: 0.3084, g_loss: 3.5694, D(x): 0.91, D(G(z)): 0.11
# Saving fake_images-0031.png
# Epoch [31/300], Step [200/600], d_loss: 0.2163, g_loss: 4.0039, D(x): 0.95, D(G(z)): 0.11
# Epoch [31/300], Step [400/600], d_loss: 0.3158, g_loss: 3.5165, D(x): 0.94, D(G(z)): 0.16
# Epoch [31/300], Step [600/600], d_loss: 0.4695, g_loss: 5.2881, D(x): 0.88, D(G(z)): 0.13
# Saving fake_images-0032.png
# Epoch [32/300], Step [200/600], d_loss: 0.2799, g_loss: 3.8594, D(x): 0.91, D(G(z)): 0.08
# Epoch [32/300], Step [400/600], d_loss: 0.4883, g_loss: 3.0043, D(x): 0.86, D(G(z)): 0.12
# Epoch [32/300], Step [600/600], d_loss: 0.4021, g_loss: 3.0369, D(x): 0.83, D(G(z)): 0.07
# Saving fake_images-0033.png
# Epoch [33/300], Step [200/600], d_loss: 0.3624, g_loss: 3.5185, D(x): 0.90, D(G(z)): 0.12
# Epoch [33/300], Step [400/600], d_loss: 0.5123, g_loss: 3.7238, D(x): 0.84, D(G(z)): 0.13
# Epoch [33/300], Step [600/600], d_loss: 0.3978, g_loss: 3.0261, D(x): 0.87, D(G(z)): 0.13
# Saving fake_images-0034.png
# Epoch [34/300], Step [200/600], d_loss: 0.4852, g_loss: 2.7526, D(x): 0.87, D(G(z)): 0.20
# Epoch [34/300], Step [400/600], d_loss: 0.6961, g_loss: 2.1337, D(x): 0.85, D(G(z)): 0.24
# Epoch [34/300], Step [600/600], d_loss: 0.3967, g_loss: 4.1733, D(x): 0.86, D(G(z)): 0.12
# Saving fake_images-0035.png
# Epoch [35/300], Step [200/600], d_loss: 0.5789, g_loss: 2.7417, D(x): 0.79, D(G(z)): 0.08
# Epoch [35/300], Step [400/600], d_loss: 0.4379, g_loss: 4.2474, D(x): 0.89, D(G(z)): 0.13
# Epoch [35/300], Step [600/600], d_loss: 0.2909, g_loss: 3.6349, D(x): 0.93, D(G(z)): 0.13
# Saving fake_images-0036.png
# Epoch [36/300], Step [200/600], d_loss: 0.8339, g_loss: 2.7918, D(x): 0.94, D(G(z)): 0.40
# Epoch [36/300], Step [400/600], d_loss: 0.4949, g_loss: 4.0942, D(x): 0.81, D(G(z)): 0.08
# Epoch [36/300], Step [600/600], d_loss: 0.5430, g_loss: 2.7291, D(x): 0.90, D(G(z)): 0.23
# Saving fake_images-0037.png
# Epoch [37/300], Step [200/600], d_loss: 0.4816, g_loss: 3.5884, D(x): 0.85, D(G(z)): 0.16
# Epoch [37/300], Step [400/600], d_loss: 0.5589, g_loss: 3.1176, D(x): 0.82, D(G(z)): 0.12
# Epoch [37/300], Step [600/600], d_loss: 0.3225, g_loss: 4.5312, D(x): 0.88, D(G(z)): 0.06
# Saving fake_images-0038.png
# Epoch [38/300], Step [200/600], d_loss: 0.3981, g_loss: 2.7089, D(x): 0.88, D(G(z)): 0.14
# Epoch [38/300], Step [400/600], d_loss: 0.4205, g_loss: 4.0079, D(x): 0.91, D(G(z)): 0.14
# Epoch [38/300], Step [600/600], d_loss: 0.2789, g_loss: 4.3758, D(x): 0.88, D(G(z)): 0.07
# Saving fake_images-0039.png
# Epoch [39/300], Step [200/600], d_loss: 0.4094, g_loss: 3.6992, D(x): 0.84, D(G(z)): 0.08
# Epoch [39/300], Step [400/600], d_loss: 0.3886, g_loss: 4.5837, D(x): 0.93, D(G(z)): 0.16
# Epoch [39/300], Step [600/600], d_loss: 0.2848, g_loss: 3.4260, D(x): 0.91, D(G(z)): 0.10
# Saving fake_images-0040.png
# Epoch [40/300], Step [200/600], d_loss: 0.4225, g_loss: 3.5896, D(x): 0.93, D(G(z)): 0.20
# Epoch [40/300], Step [400/600], d_loss: 0.4508, g_loss: 3.2344, D(x): 0.84, D(G(z)): 0.10
# Epoch [40/300], Step [600/600], d_loss: 0.4309, g_loss: 5.3547, D(x): 0.84, D(G(z)): 0.06
# Saving fake_images-0041.png
# Epoch [41/300], Step [200/600], d_loss: 0.3809, g_loss: 4.2530, D(x): 0.84, D(G(z)): 0.04
# Epoch [41/300], Step [400/600], d_loss: 0.3180, g_loss: 4.8420, D(x): 0.85, D(G(z)): 0.03
# Epoch [41/300], Step [600/600], d_loss: 0.4592, g_loss: 3.8464, D(x): 0.91, D(G(z)): 0.19
# Saving fake_images-0042.png
# Epoch [42/300], Step [200/600], d_loss: 0.4654, g_loss: 3.1788, D(x): 0.85, D(G(z)): 0.15
# Epoch [42/300], Step [400/600], d_loss: 0.3277, g_loss: 3.6953, D(x): 0.90, D(G(z)): 0.12
# Epoch [42/300], Step [600/600], d_loss: 0.5279, g_loss: 3.8374, D(x): 0.85, D(G(z)): 0.15
# Saving fake_images-0043.png
# Epoch [43/300], Step [200/600], d_loss: 0.6624, g_loss: 3.0894, D(x): 0.74, D(G(z)): 0.09
# Epoch [43/300], Step [400/600], d_loss: 0.7677, g_loss: 2.4444, D(x): 0.79, D(G(z)): 0.24
# Epoch [43/300], Step [600/600], d_loss: 0.6472, g_loss: 2.2476, D(x): 0.87, D(G(z)): 0.26
# Saving fake_images-0044.png
# Epoch [44/300], Step [200/600], d_loss: 0.5353, g_loss: 3.5848, D(x): 0.81, D(G(z)): 0.13
# Epoch [44/300], Step [400/600], d_loss: 0.5337, g_loss: 2.8630, D(x): 0.90, D(G(z)): 0.24
# Epoch [44/300], Step [600/600], d_loss: 0.7046, g_loss: 2.0216, D(x): 0.78, D(G(z)): 0.23
# Saving fake_images-0045.png
# Epoch [45/300], Step [200/600], d_loss: 0.3655, g_loss: 3.0052, D(x): 0.86, D(G(z)): 0.11
# Epoch [45/300], Step [400/600], d_loss: 0.5153, g_loss: 2.5615, D(x): 0.88, D(G(z)): 0.23
# Epoch [45/300], Step [600/600], d_loss: 0.4625, g_loss: 2.2469, D(x): 0.83, D(G(z)): 0.14
# Saving fake_images-0046.png
# Epoch [46/300], Step [200/600], d_loss: 0.6694, g_loss: 2.4722, D(x): 0.79, D(G(z)): 0.18
# Epoch [46/300], Step [400/600], d_loss: 0.8168, g_loss: 1.5982, D(x): 0.83, D(G(z)): 0.28
# Epoch [46/300], Step [600/600], d_loss: 0.6052, g_loss: 3.2013, D(x): 0.78, D(G(z)): 0.16
# Saving fake_images-0047.png
# Epoch [47/300], Step [200/600], d_loss: 0.4372, g_loss: 3.0645, D(x): 0.89, D(G(z)): 0.20
# Epoch [47/300], Step [400/600], d_loss: 0.3308, g_loss: 3.1646, D(x): 0.87, D(G(z)): 0.10
# Epoch [47/300], Step [600/600], d_loss: 0.5116, g_loss: 2.2538, D(x): 0.83, D(G(z)): 0.16
# Saving fake_images-0048.png
# Epoch [48/300], Step [200/600], d_loss: 0.4887, g_loss: 3.4701, D(x): 0.80, D(G(z)): 0.08
# Epoch [48/300], Step [400/600], d_loss: 0.5826, g_loss: 2.3585, D(x): 0.88, D(G(z)): 0.26
# Epoch [48/300], Step [600/600], d_loss: 0.5174, g_loss: 3.0459, D(x): 0.81, D(G(z)): 0.13
# Saving fake_images-0049.png
# Epoch [49/300], Step [200/600], d_loss: 0.3962, g_loss: 2.6242, D(x): 0.89, D(G(z)): 0.17
# Epoch [49/300], Step [400/600], d_loss: 0.4517, g_loss: 2.5460, D(x): 0.86, D(G(z)): 0.19
# Epoch [49/300], Step [600/600], d_loss: 0.5851, g_loss: 2.8031, D(x): 0.77, D(G(z)): 0.14
# Saving fake_images-0050.png
# Epoch [50/300], Step [200/600], d_loss: 0.4394, g_loss: 2.4779, D(x): 0.91, D(G(z)): 0.21
# Epoch [50/300], Step [400/600], d_loss: 0.3781, g_loss: 2.7682, D(x): 0.85, D(G(z)): 0.09
# Epoch [50/300], Step [600/600], d_loss: 0.7485, g_loss: 3.4542, D(x): 0.70, D(G(z)): 0.09
# Saving fake_images-0051.png
# Epoch [51/300], Step [200/600], d_loss: 0.7011, g_loss: 2.2779, D(x): 0.86, D(G(z)): 0.26
# Epoch [51/300], Step [400/600], d_loss: 0.5086, g_loss: 3.0220, D(x): 0.80, D(G(z)): 0.11
# Epoch [51/300], Step [600/600], d_loss: 0.6434, g_loss: 2.9950, D(x): 0.80, D(G(z)): 0.20
# Saving fake_images-0052.png
# Epoch [52/300], Step [200/600], d_loss: 0.5472, g_loss: 3.1586, D(x): 0.79, D(G(z)): 0.11
# Epoch [52/300], Step [400/600], d_loss: 0.5010, g_loss: 3.2628, D(x): 0.80, D(G(z)): 0.09
# Epoch [52/300], Step [600/600], d_loss: 0.4392, g_loss: 4.0165, D(x): 0.81, D(G(z)): 0.06
# Saving fake_images-0053.png
# Epoch [53/300], Step [200/600], d_loss: 0.3245, g_loss: 3.5458, D(x): 0.90, D(G(z)): 0.12
# Epoch [53/300], Step [400/600], d_loss: 0.4971, g_loss: 3.8222, D(x): 0.80, D(G(z)): 0.07
# Epoch [53/300], Step [600/600], d_loss: 0.4544, g_loss: 3.4788, D(x): 0.85, D(G(z)): 0.13
# Saving fake_images-0054.png
# Epoch [54/300], Step [200/600], d_loss: 0.6212, g_loss: 2.3938, D(x): 0.87, D(G(z)): 0.24
# Epoch [54/300], Step [400/600], d_loss: 0.6513, g_loss: 2.8400, D(x): 0.76, D(G(z)): 0.10
# Epoch [54/300], Step [600/600], d_loss: 0.4486, g_loss: 2.7654, D(x): 0.87, D(G(z)): 0.17
# Saving fake_images-0055.png
# Epoch [55/300], Step [200/600], d_loss: 0.5776, g_loss: 2.2354, D(x): 0.86, D(G(z)): 0.22
# Epoch [55/300], Step [400/600], d_loss: 0.7698, g_loss: 2.7012, D(x): 0.78, D(G(z)): 0.24
# Epoch [55/300], Step [600/600], d_loss: 0.7454, g_loss: 2.7085, D(x): 0.92, D(G(z)): 0.36
# Saving fake_images-0056.png
# Epoch [56/300], Step [200/600], d_loss: 0.6123, g_loss: 2.4994, D(x): 0.86, D(G(z)): 0.25
# Epoch [56/300], Step [400/600], d_loss: 0.5448, g_loss: 2.7936, D(x): 0.86, D(G(z)): 0.21
# Epoch [56/300], Step [600/600], d_loss: 0.9365, g_loss: 3.0716, D(x): 0.72, D(G(z)): 0.20
# Saving fake_images-0057.png
# Epoch [57/300], Step [200/600], d_loss: 0.5581, g_loss: 2.3186, D(x): 0.84, D(G(z)): 0.22
# Epoch [57/300], Step [400/600], d_loss: 0.5904, g_loss: 2.3662, D(x): 0.80, D(G(z)): 0.16
# Epoch [57/300], Step [600/600], d_loss: 0.5430, g_loss: 2.0870, D(x): 0.85, D(G(z)): 0.21
# Saving fake_images-0058.png
# Epoch [58/300], Step [200/600], d_loss: 0.7516, g_loss: 1.8139, D(x): 0.79, D(G(z)): 0.23
# Epoch [58/300], Step [400/600], d_loss: 0.5823, g_loss: 2.8193, D(x): 0.75, D(G(z)): 0.15
# Epoch [58/300], Step [600/600], d_loss: 0.6596, g_loss: 2.5076, D(x): 0.76, D(G(z)): 0.15
# Saving fake_images-0059.png
# Epoch [59/300], Step [200/600], d_loss: 0.5352, g_loss: 3.0947, D(x): 0.85, D(G(z)): 0.20
# Epoch [59/300], Step [400/600], d_loss: 0.6113, g_loss: 2.7163, D(x): 0.81, D(G(z)): 0.16
# Epoch [59/300], Step [600/600], d_loss: 0.8604, g_loss: 1.9742, D(x): 0.73, D(G(z)): 0.21
# Saving fake_images-0060.png
# Epoch [60/300], Step [200/600], d_loss: 0.7019, g_loss: 1.7896, D(x): 0.75, D(G(z)): 0.18
# Epoch [60/300], Step [400/600], d_loss: 0.7875, g_loss: 2.1103, D(x): 0.73, D(G(z)): 0.22
# Epoch [60/300], Step [600/600], d_loss: 0.7866, g_loss: 2.2167, D(x): 0.83, D(G(z)): 0.32
# Saving fake_images-0061.png
# Epoch [61/300], Step [200/600], d_loss: 0.4839, g_loss: 3.2738, D(x): 0.81, D(G(z)): 0.15
# Epoch [61/300], Step [400/600], d_loss: 0.7222, g_loss: 2.8815, D(x): 0.78, D(G(z)): 0.22
# Epoch [61/300], Step [600/600], d_loss: 0.5103, g_loss: 2.4853, D(x): 0.86, D(G(z)): 0.21
# Saving fake_images-0062.png
# Epoch [62/300], Step [200/600], d_loss: 0.6572, g_loss: 2.2045, D(x): 0.80, D(G(z)): 0.24
# Epoch [62/300], Step [400/600], d_loss: 0.5692, g_loss: 2.6618, D(x): 0.80, D(G(z)): 0.20
# Epoch [62/300], Step [600/600], d_loss: 0.4665, g_loss: 2.7182, D(x): 0.87, D(G(z)): 0.21
# Saving fake_images-0063.png
# Epoch [63/300], Step [200/600], d_loss: 0.4491, g_loss: 2.1041, D(x): 0.87, D(G(z)): 0.19
# Epoch [63/300], Step [400/600], d_loss: 0.5245, g_loss: 3.7131, D(x): 0.85, D(G(z)): 0.20
# Epoch [63/300], Step [600/600], d_loss: 0.5759, g_loss: 2.2629, D(x): 0.85, D(G(z)): 0.23
# Saving fake_images-0064.png
# Epoch [64/300], Step [200/600], d_loss: 0.5771, g_loss: 3.4815, D(x): 0.79, D(G(z)): 0.17
# Epoch [64/300], Step [400/600], d_loss: 0.5841, g_loss: 2.3291, D(x): 0.84, D(G(z)): 0.22
# Epoch [64/300], Step [600/600], d_loss: 0.5791, g_loss: 2.1512, D(x): 0.81, D(G(z)): 0.19
# Saving fake_images-0065.png
# Epoch [65/300], Step [200/600], d_loss: 0.5653, g_loss: 2.6891, D(x): 0.88, D(G(z)): 0.25
# Epoch [65/300], Step [400/600], d_loss: 0.5334, g_loss: 2.7320, D(x): 0.85, D(G(z)): 0.18
# Epoch [65/300], Step [600/600], d_loss: 0.4672, g_loss: 2.5163, D(x): 0.86, D(G(z)): 0.19
# Saving fake_images-0066.png
# Epoch [66/300], Step [200/600], d_loss: 0.5447, g_loss: 1.8985, D(x): 0.94, D(G(z)): 0.29
# Epoch [66/300], Step [400/600], d_loss: 0.6153, g_loss: 2.2688, D(x): 0.80, D(G(z)): 0.18
# Epoch [66/300], Step [600/600], d_loss: 0.6385, g_loss: 2.1321, D(x): 0.84, D(G(z)): 0.24
# Saving fake_images-0067.png
# Epoch [67/300], Step [200/600], d_loss: 0.6036, g_loss: 2.6914, D(x): 0.81, D(G(z)): 0.19
# Epoch [67/300], Step [400/600], d_loss: 0.4780, g_loss: 2.5711, D(x): 0.85, D(G(z)): 0.15
# Epoch [67/300], Step [600/600], d_loss: 0.8623, g_loss: 2.0081, D(x): 0.85, D(G(z)): 0.37
# Saving fake_images-0068.png
# Epoch [68/300], Step [200/600], d_loss: 0.5672, g_loss: 2.2677, D(x): 0.81, D(G(z)): 0.15
# Epoch [68/300], Step [400/600], d_loss: 0.8533, g_loss: 2.5317, D(x): 0.75, D(G(z)): 0.26
# Epoch [68/300], Step [600/600], d_loss: 0.5187, g_loss: 2.4996, D(x): 0.82, D(G(z)): 0.18
# Saving fake_images-0069.png
# Epoch [69/300], Step [200/600], d_loss: 0.6480, g_loss: 2.4466, D(x): 0.84, D(G(z)): 0.26
# Epoch [69/300], Step [400/600], d_loss: 0.6464, g_loss: 2.3439, D(x): 0.81, D(G(z)): 0.21
# Epoch [69/300], Step [600/600], d_loss: 0.6833, g_loss: 2.5149, D(x): 0.81, D(G(z)): 0.24
# Saving fake_images-0070.png
# Epoch [70/300], Step [200/600], d_loss: 0.6207, g_loss: 2.3007, D(x): 0.80, D(G(z)): 0.21
# Epoch [70/300], Step [400/600], d_loss: 0.6162, g_loss: 2.2061, D(x): 0.88, D(G(z)): 0.31
# Epoch [70/300], Step [600/600], d_loss: 0.7375, g_loss: 2.1736, D(x): 0.77, D(G(z)): 0.22
# Saving fake_images-0071.png
# Epoch [71/300], Step [200/600], d_loss: 0.9320, g_loss: 2.4434, D(x): 0.75, D(G(z)): 0.30
# Epoch [71/300], Step [400/600], d_loss: 0.8253, g_loss: 2.6431, D(x): 0.68, D(G(z)): 0.12
# Epoch [71/300], Step [600/600], d_loss: 0.8993, g_loss: 2.2655, D(x): 0.66, D(G(z)): 0.13
# Saving fake_images-0072.png
# Epoch [72/300], Step [200/600], d_loss: 0.7222, g_loss: 2.2327, D(x): 0.78, D(G(z)): 0.25
# Epoch [72/300], Step [400/600], d_loss: 0.8135, g_loss: 1.9500, D(x): 0.74, D(G(z)): 0.26
# Epoch [72/300], Step [600/600], d_loss: 0.6102, g_loss: 3.0704, D(x): 0.76, D(G(z)): 0.14
# Saving fake_images-0073.png
# Epoch [73/300], Step [200/600], d_loss: 0.7313, g_loss: 2.2306, D(x): 0.77, D(G(z)): 0.24
# Epoch [73/300], Step [400/600], d_loss: 0.6924, g_loss: 2.3413, D(x): 0.80, D(G(z)): 0.26
# Epoch [73/300], Step [600/600], d_loss: 0.7830, g_loss: 2.2846, D(x): 0.73, D(G(z)): 0.19
# Saving fake_images-0074.png
# Epoch [74/300], Step [200/600], d_loss: 0.5739, g_loss: 2.7349, D(x): 0.83, D(G(z)): 0.24
# Epoch [74/300], Step [400/600], d_loss: 0.7530, g_loss: 2.0677, D(x): 0.73, D(G(z)): 0.18
# Epoch [74/300], Step [600/600], d_loss: 1.2033, g_loss: 1.8602, D(x): 0.69, D(G(z)): 0.38
# Saving fake_images-0075.png
# Epoch [75/300], Step [200/600], d_loss: 0.6414, g_loss: 2.4400, D(x): 0.78, D(G(z)): 0.18
# Epoch [75/300], Step [400/600], d_loss: 0.8176, g_loss: 1.8940, D(x): 0.77, D(G(z)): 0.24
# Epoch [75/300], Step [600/600], d_loss: 0.9481, g_loss: 2.0824, D(x): 0.76, D(G(z)): 0.34
# Saving fake_images-0076.png
# Epoch [76/300], Step [200/600], d_loss: 0.8678, g_loss: 2.0874, D(x): 0.67, D(G(z)): 0.21
# Epoch [76/300], Step [400/600], d_loss: 0.6453, g_loss: 2.0051, D(x): 0.76, D(G(z)): 0.18
# Epoch [76/300], Step [600/600], d_loss: 0.4682, g_loss: 2.4159, D(x): 0.81, D(G(z)): 0.15
# Saving fake_images-0077.png
# Epoch [77/300], Step [200/600], d_loss: 0.8049, g_loss: 2.6891, D(x): 0.65, D(G(z)): 0.14
# Epoch [77/300], Step [400/600], d_loss: 0.7495, g_loss: 2.0624, D(x): 0.85, D(G(z)): 0.32
# Epoch [77/300], Step [600/600], d_loss: 0.6651, g_loss: 2.0690, D(x): 0.88, D(G(z)): 0.30
# Saving fake_images-0078.png
# Epoch [78/300], Step [200/600], d_loss: 0.8450, g_loss: 2.3682, D(x): 0.83, D(G(z)): 0.35
# Epoch [78/300], Step [400/600], d_loss: 0.7019, g_loss: 1.7981, D(x): 0.74, D(G(z)): 0.20
# Epoch [78/300], Step [600/600], d_loss: 0.8967, g_loss: 1.7552, D(x): 0.80, D(G(z)): 0.34
# Saving fake_images-0079.png
# Epoch [79/300], Step [200/600], d_loss: 0.6406, g_loss: 2.0738, D(x): 0.79, D(G(z)): 0.21
# Epoch [79/300], Step [400/600], d_loss: 0.9318, g_loss: 2.0546, D(x): 0.75, D(G(z)): 0.32
# Epoch [79/300], Step [600/600], d_loss: 0.6730, g_loss: 1.7820, D(x): 0.75, D(G(z)): 0.19
# Saving fake_images-0080.png
# Epoch [80/300], Step [200/600], d_loss: 0.8670, g_loss: 3.1174, D(x): 0.72, D(G(z)): 0.24
# Epoch [80/300], Step [400/600], d_loss: 0.6574, g_loss: 2.5245, D(x): 0.79, D(G(z)): 0.20
# Epoch [80/300], Step [600/600], d_loss: 0.6033, g_loss: 2.2673, D(x): 0.79, D(G(z)): 0.21
# Saving fake_images-0081.png
# Epoch [81/300], Step [200/600], d_loss: 0.7064, g_loss: 2.0726, D(x): 0.76, D(G(z)): 0.21
# Epoch [81/300], Step [400/600], d_loss: 0.7643, g_loss: 1.7957, D(x): 0.72, D(G(z)): 0.19
# Epoch [81/300], Step [600/600], d_loss: 0.6633, g_loss: 2.2363, D(x): 0.77, D(G(z)): 0.21
# Saving fake_images-0082.png
# Epoch [82/300], Step [200/600], d_loss: 0.8167, g_loss: 2.7359, D(x): 0.73, D(G(z)): 0.23
# Epoch [82/300], Step [400/600], d_loss: 0.7283, g_loss: 2.4968, D(x): 0.74, D(G(z)): 0.21
# Epoch [82/300], Step [600/600], d_loss: 0.7812, g_loss: 1.9319, D(x): 0.74, D(G(z)): 0.21
# Saving fake_images-0083.png
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-32-5d7f5abf5d38> in <module>()
#      10         # Train the discriminator and generator
#      11         d_loss, real_score, fake_score = train_discriminator(images)
# ---> 12         g_loss, fake_images = train_generator()
#      13
#      14         # Inspect the losses
#
# <ipython-input-26-dfda4011bc1d> in train_generator()
#       1 def train_generator():
#       2     # Generate fake images and calculate loss
# ----> 3     z = torch.randn(batch_size, latent_size).to(device)
#       4     fake_images = G(z)
#       5     labels = torch.ones(batch_size, 1).to(device)
#
# KeyboardInterrupt:

# %%
Image('./samples/fake_images-0050.png')

# %%
Image('./samples/fake_images-0083.png')

# %%
plt.plot(d_losses, '-')
plt.plot(g_losses, '-')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['Discriminator', 'Generator'])
plt.title('Losses');

# %%
plt.plot(real_scores, '-')
plt.plot(fake_scores, '-')
plt.xlabel('epoch')
plt.ylabel('score')
plt.legend(['Real Score', 'Fake score'])
plt.title('Scores');
